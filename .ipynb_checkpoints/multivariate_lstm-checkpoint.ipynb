# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib.pylab import rcParams
rcParams['figure.figsize']=20,10

from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
from keras.models import Sequential
from keras.layers import LSTM,Dropout,Dense

# %%
df=pd.read_excel("dse13-21.xlsx")
df.head()
# Out:
#         Date    Price     Open     High      Low Vol.  Change %
# 0 2021-03-23  5413.73  5412.19  5451.92  5400.68    -    0.0003
# 1 2021-03-22  5412.19  5349.77  5418.69  5289.81    -    0.0117
# 2 2021-03-21  5349.77  5434.69  5434.69  5337.38    -   -0.0156
# 3 2021-03-18  5434.69  5516.40  5516.40  5414.96    -   -0.0148
# 4 2021-03-16  5516.40  5532.97  5572.42  5503.38    -   -0.0030

# %%
df["Date"]=pd.to_datetime(df.Date,format="%Y-%m-%d")
df.index=df['Date']
df.index
# Out:
# DatetimeIndex(['2021-03-23', '2021-03-22', '2021-03-21', '2021-03-18',
#                '2021-03-16', '2021-03-15', '2021-03-14', '2021-03-11',
#                '2021-03-10', '2021-03-09',
#                ...
#                '2013-02-12', '2013-02-11', '2013-02-10', '2013-02-07',
#                '2013-02-06', '2013-02-05', '2013-02-04', '2013-02-03',
#                '2013-01-31', '2013-01-30'],
#               dtype='datetime64[ns]', name='Date', length=1931, freq=None)

# %%
import seaborn as sns
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(11, 4)})

# %%
#plot
plt.figure(figsize=(16,8))
plt.plot(df['Price'], label='Discharge history')

# %%
data=df.sort_index(ascending=True,axis=0)
new_dataset=pd.DataFrame(index=range(0,len(df)),columns=['Date','Price','Open'])
for i in range(0,len(data)):
    new_dataset["Date"][i]=data['Date'][i]
    new_dataset["Price"][i]=data['Price'][i]
    new_dataset["Open"][i]=data["Open"][i]

# %%
test_data=df.sort_index(ascending=True,axis=0)
test_dataset=pd.DataFrame(index=range(0,len(df)),columns=['Date','Price'])
for i in range(0,len(data)):
    test_dataset["Date"][i]=data['Date'][i]    
    test_dataset["Price"][i]=data["Price"][i]

# %%
#test_dataset

# %%
new_dataset.index=new_dataset.Date
new_dataset.drop("Date",axis=1,inplace=True)

final_dataset=new_dataset.values

train_data=final_dataset[0:1500,:]
valid_data=final_dataset[1500:,:]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-178c8413011f> in <module>
# ----> 1 new_dataset.index=new_dataset.Date
#       2 new_dataset.drop("Date",axis=1,inplace=True)
#       3
#       4 final_dataset=new_dataset.values
#       5
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Date'

# %%
test_dataset.index=test_dataset.Date
test_dataset.drop("Date",axis=1,inplace=True)

test_final_dataset=test_dataset.values

train_data=test_final_dataset[0:1500,:]
valid_data=test_final_dataset[1500:,:]

# %%
train_data=new_dataset.iloc[0:1500]

# %%
test_train_data=new_dataset.iloc[0:1500]

# %%
#train_data

# %%
scaler=MinMaxScaler(feature_range=(0,1))
scaled_data=scaler.fit_transform(final_dataset)

x_train_data,y_train_data=[],[]

for i in range(60,len(train_data)):
    x_train_data.append(scaled_data[i-60:i,0])
    y_train_data.append(scaled_data[i,0])
    
x_train_data,y_train_data=np.array(x_train_data),np.array(y_train_data)

x_train_data=np.reshape(x_train_data,(x_train_data.shape[0],x_train_data.shape[1],1))

# %%
scaler=MinMaxScaler(feature_range=(0,1))
scaled_data=scaler.fit_transform(test_final_dataset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-1c0f5fed6f0b> in <module>
#       1 scaler=MinMaxScaler(feature_range=(0,1))
# ----> 2 scaled_data=scaler.fit_transform(test_final_dataset)
#
# NameError: name 'test_final_dataset' is not defined

# %%
x_train_data.shape[0]
# Out:
# 1440

# %%
lstm_model=Sequential()
lstm_model.add(LSTM(units=50,return_sequences=True,input_shape=(x_train_data.shape[1],1)))
lstm_model.add(LSTM(units=50))
lstm_model.add(Dense(1))
lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 60, 50)            10400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# =================================================================
# Total params: 30,651
# Trainable params: 30,651
# Non-trainable params: 0
# _________________________________________________________________

# %%
# COMPILE THE MODEL

lstm_model.compile(loss='mean_squared_error',optimizer='adam')

# %%
#  FIT THE MODEL
lstm_model.fit(x_train_data,y_train_data,epochs=1,batch_size=1,verbose=2)
# Out:
# 1440/1440 - 43s - loss: 0.0031

# %%
# Take a sample of a dataset to make stock price predictions using the LSTM model

inputs_data=test_dataset[len(test_dataset)-len(valid_data)-60:].values
inputs_data=inputs_data.reshape(-1,1)
inputs_data=scaler.transform(inputs_data)


X_test=[]
for i in range(60,inputs_data.shape[0]):
    X_test.append(inputs_data[i-60:i,0])
X_test=np.array(X_test)

X_test=np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))
discharge=lstm_model.predict(X_test)
discharge=scaler.inverse_transform(discharge)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-16-05192448ed7a> in <module>
#       3 inputs_data=test_dataset[len(test_dataset)-len(valid_data)-60:].values
#       4 inputs_data=inputs_data.reshape(-1,1)
# ----> 5 inputs_data=scaler.transform(inputs_data)
#       6
#       7
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in transform(self, X)
#     403             Transformed data.
#     404         """
# --> 405         check_is_fitted(self)
#     406
#     407         X = check_array(X, copy=self.copy, dtype=FLOAT_DTYPES,
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1017
#    1018     if not attrs:
# -> 1019         raise NotFittedError(msg % {'name': type(estimator).__name__})
#    1020
#    1021
#
# NotFittedError: This MinMaxScaler instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
inputs_data
# Out:
# array([[0.82356392],
#        [0.84485454],
#        [0.83520302],
#        [0.83732863],
#        [0.85795672],
#        [0.86650403],
#        [0.86286012],
#        [0.85070342],
#        [0.85771172],
#        [0.84376413],
#        [0.82199041],
#        [0.8151995 ],
#        [0.82442659],
#        [0.81482338],
#        [0.80990963],
#        [0.81885376],
#        [0.80222499],
#        [0.7919351 ],
#        [0.79125877],
#        [0.79690406],
#        [0.79758729],
#        [0.80639685],
#        [0.78869492],
#        [0.79262868],
#        [0.7960483 ],
#        [0.78515799],
#        [0.79948516],
#        [0.79356727],
#        [0.78431258],
#        [0.78431258],
#        [0.78819458],
#        [0.77416416],
#        [0.77591365],
#        [0.77553408],
#        [0.77624837],
#        [0.78370526],
#        [0.77706617],
#        [0.77417106],
#        [0.76408821],
#        [0.76498539],
#        [0.74741804],
#        [0.75652435],
#        [0.745917  ],
#        [0.73542697],
#        [0.71538549],
#        [0.72159669],
#        [0.7120763 ],
#        [0.71311495],
#        [0.70842549],
#        [0.71228334],
#        [0.71887067],
#        [0.69472289],
#        [0.69738681],
#        [0.68840817],
#        [0.66713136],
#        [0.64867719],
#        [0.62895662],
#        [0.6513135 ],
#        [0.64547497],
#        [0.62457772],
#        [0.62820093],
#        [0.64959506],
#        [0.65039562],
#        [0.62869782],
#        [0.6216274 ],
#        [0.63053358],
#        [0.62087861],
#        [0.59923257],
#        [0.60868395],
#        [0.63763505],
#        [0.67495402],
#        [0.65672759],
#        [0.63875307],
#        [0.63267644],
#        [0.63386692],
#        [0.63320784],
#        [0.6242016 ],
#        [0.61388066],
#        [0.60633059],
#        [0.61832166],
#        [0.65452607],
#        [0.63397389],
#        [0.62041277],
#        [0.62527821],
#        [0.62515744],
#        [0.62609947],
#        [0.62617538],
#        [0.6521313 ],
#        [0.66090635],
#        [0.66903267],
#        [0.67773526],
#        [0.68761452],
#        [0.70293203],
#        [0.70074086],
#        [0.70235232],
#        [0.68735227],
#        [0.66818726],
#        [0.67679323],
#        [0.68064762],
#        [0.67520247],
#        [0.67115483],
#        [0.67218313],
#        [0.67014379],
#        [0.68040607],
#        [0.68707967],
#        [0.6841742 ],
#        [0.67151025],
#        [0.66712446],
#        [0.67008513],
#        [0.65362199],
#        [0.64862888],
#        [0.63531965],
#        [0.6182699 ],
#        [0.6153955 ],
#        [0.60062319],
#        [0.57025387],
#        [0.58162727],
#        [0.5846259 ],
#        [0.58378393],
#        [0.55032971],
#        [0.52710672],
#        [0.5655161 ],
#        [0.56535392],
#        [0.5846673 ],
#        [0.58490195],
#        [0.59415319],
#        [0.5818274 ],
#        [0.58657897],
#        [0.59725534],
#        [0.5983354 ],
#        [0.59402551],
#        [0.60331471],
#        [0.60328366],
#        [0.6081905 ],
#        [0.61340446],
#        [0.61710703],
#        [0.61718639],
#        [0.61577852],
#        [0.62041622],
#        [0.61588549],
#        [0.59588542],
#        [0.60035059],
#        [0.58699305],
#        [0.5717342 ],
#        [0.56307648],
#        [0.55025725],
#        [0.54111988],
#        [0.5339839 ],
#        [0.54317648],
#        [0.55034696],
#        [0.54177896],
#        [0.51562635],
#        [0.5158748 ],
#        [0.51875265],
#        [0.52479132],
#        [0.51418052],
#        [0.50004313],
#        [0.48899065],
#        [0.51141308],
#        [0.53876652],
#        [0.5244428 ],
#        [0.52203079],
#        [0.52780375],
#        [0.53031239],
#        [0.52061601],
#        [0.52122333],
#        [0.51673056],
#        [0.51723091],
#        [0.5099362 ],
#        [0.50221705],
#        [0.49115421],
#        [0.47319694],
#        [0.45651641],
#        [0.43906639],
#        [0.47714105],
#        [0.46333148],
#        [0.45966342],
#        [0.46349366],
#        [0.45636113],
#        [0.43816231],
#        [0.44435281],
#        [0.46001194],
#        [0.45333145],
#        [0.43489798],
#        [0.42507048],
#        [0.42937001],
#        [0.42926649],
#        [0.43933554],
#        [0.42769989],
#        [0.43644388],
#        [0.45403883],
#        [0.45998088],
#        [0.46327972],
#        [0.46248952],
#        [0.44799326],
#        [0.43874202],
#        [0.44116784],
#        [0.44276205],
#        [0.44288628],
#        [0.43238244],
#        [0.43746528],
#        [0.43117126],
#        [0.43296561],
#        [0.44286212],
#        [0.44563646],
#        [0.44601258],
#        [0.45546051],
#        [0.44710299],
#        [0.43425271],
#        [0.43619543],
#        [0.42527407],
#        [0.39928019],
#        [0.37779979],
#        [0.3685451 ],
#        [0.37042916],
#        [0.37113655],
#        [0.36563273],
#        [0.33848633],
#        [0.33784106],
#        [0.35125725],
#        [0.34232692],
#        [0.32972854],
#        [0.32842763],
#        [0.33814471],
#        [0.34335867],
#        [0.34991149],
#        [0.35003571],
#        [0.35210611],
#        [0.33169542],
#        [0.30816531],
#        [0.29073254],
#        [0.27241985],
#        [0.26173313],
#        [0.26692639],
#        [0.23622925],
#        [0.20612217],
#        [0.21715396],
#        [0.24531831],
#        [0.32545661],
#        [0.34434211],
#        [0.33444215],
#        [0.34554985],
#        [0.37094676],
#        [0.37588466],
#        [0.36374177],
#        [0.36987015],
#        [0.35987012],
#        [0.35568101],
#        [0.3597735 ],
#        [0.36852439],
#        [0.35904541],
#        [0.35438356],
#        [0.34992184],
#        [0.32776511],
#        [0.32665744],
#        [0.35632283],
#        [0.35953885],
#        [0.38844855],
#        [0.44695116],
#        [0.45867653],
#        [0.44910783],
#        [0.455181  ],
#        [0.44660265],
#        [0.43478411],
#        [0.4182209 ],
#        [0.40797242],
#        [0.38310001],
#        [0.35932836],
#        [0.33506672],
#        [0.34365888],
#        [0.35444567],
#        [0.33496665],
#        [0.32629167],
#        [0.29278569],
#        [0.19639819],
#        [0.24756124],
#        [0.27349646],
#        [0.23846528],
#        [0.18303031],
#        [0.11513497],
#        [0.05695672],
#        [0.18497993],
#        [0.1798764 ],
#        [0.18835814],
#        [0.18553204],
#        [0.19647756],
#        [0.19647756],
#        [0.21447624],
#        [0.19344442],
#        [0.18312348],
#        [0.18099096],
#        [0.17753339],
#        [0.18033879],
#        [0.17847198],
#        [0.18063554],
#        [0.18214694],
#        [0.18234017],
#        [0.18129462],
#        [0.17925183],
#        [0.18004203],
#        [0.18047336],
#        [0.18001442],
#        [0.18084603],
#        [0.18052167],
#        [0.18097371],
#        [0.18148441],
#        [0.18301996],
#        [0.18472458],
#        [0.18728498],
#        [0.18985228],
#        [0.18904137],
#        [0.18724357],
#        [0.1917743 ],
#        [0.19424498],
#        [0.20557697],
#        [0.21486272],
#        [0.22792694],
#        [0.22450733],
#        [0.22196419],
#        [0.22090483],
#        [0.21746797],
#        [0.21109459],
#        [0.21782684],
#        [0.22322368],
#        [0.22011808],
#        [0.22154666],
#        [0.23815817],
#        [0.24378621],
#        [0.24763716],
#        [0.25269583],
#        [0.26760962],
#        [0.287413  ],
#        [0.29682987],
#        [0.29960766],
#        [0.31951111],
#        [0.38173355],
#        [0.37755824],
#        [0.41217534],
#        [0.43631275],
#        [0.49019838],
#        [0.46451161],
#        [0.44210297],
#        [0.46600575],
#        [0.46762411],
#        [0.46792087],
#        [0.45670965],
#        [0.46331423],
#        [0.4791873 ],
#        [0.49492234],
#        [0.49698239],
#        [0.49114386],
#        [0.50125777],
#        [0.51378024],
#        [0.52093693],
#        [0.52460153],
#        [0.53120611],
#        [0.52891487],
#        [0.54258296],
#        [0.57114069],
#        [0.57048161],
#        [0.57338017],
#        [0.57899441],
#        [0.57479839],
#        [0.56935324],
#        [0.54286937],
#        [0.52836966],
#        [0.52907015],
#        [0.53136139],
#        [0.52889071],
#        [0.5399363 ],
#        [0.53260363],
#        [0.52601976],
#        [0.5370688 ],
#        [0.53799357],
#        [0.52028475],
#        [0.51413911],
#        [0.51607148],
#        [0.51003627],
#        [0.4898119 ],
#        [0.47302096],
#        [0.48342472],
#        [0.48314867],
#        [0.49461868],
#        [0.49646824],
#        [0.50492238],
#        [0.51013289],
#        [0.50999486],
#        [0.50902177],
#        [0.5014234 ],
#        [0.49312454],
#        [0.48296578],
#        [0.48558139],
#        [0.50303486],
#        [0.51052281],
#        [0.5138458 ],
#        [0.51094379],
#        [0.5187147 ],
#        [0.51234131],
#        [0.51386651],
#        [0.50405626],
#        [0.49855244],
#        [0.50591617],
#        [0.49304518],
#        [0.49431503],
#        [0.50593687],
#        [0.49973602],
#        [0.49726535],
#        [0.48523287],
#        [0.47578149],
#        [0.48112657],
#        [0.49102309],
#        [0.49351447],
#        [0.49790717],
#        [0.49273807],
#        [0.5055435 ],
#        [0.51620951],
#        [0.53000183],
#        [0.54709989],
#        [0.55714478],
#        [0.55587148],
#        [0.56280042],
#        [0.57135118],
#        [0.58231395],
#        [0.58941887],
#        [0.58115107],
#        [0.57596472],
#        [0.56442224],
#        [0.5784354 ],
#        [0.57266933],
#        [0.58468111],
#        [0.61403594],
#        [0.65196222],
#        [0.65739357],
#        [0.66230732],
#        [0.6774247 ],
#        [0.75226623],
#        [0.7637811 ],
#        [0.74907436],
#        [0.75959544],
#        [0.75323586],
#        [0.75747328],
#        [0.78670389],
#        [0.83579653],
#        [0.80438856],
#        [0.85245636],
#        [0.83214228],
#        [0.81533408],
#        [0.82191795],
#        [0.8242506 ],
#        [0.82722508],
#        [0.8201029 ],
#        [0.81126229],
#        [0.77863623],
#        [0.78532017],
#        [0.78863626],
#        [0.76293224],
#        [0.7456582 ],
#        [0.7335429 ],
#        [0.7394677 ],
#        [0.76217654],
#        [0.71286995],
#        [0.66858754],
#        [0.71071674],
#        [0.71446416],
#        [0.70604798],
#        [0.69315284],
#        [0.7267796 ],
#        [0.72067191],
#        [0.71248693],
#        [0.70293203],
#        [0.67161032],
#        [0.64831832],
#        [0.6717587 ],
#        [0.6823695 ],
#        [0.67836673],
#        [0.68596855],
#        [0.71407079],
#        [0.70710389],
#        [0.71666569],
#        [0.74030621],
#        [0.7472386 ],
#        [0.74275274],
#        [0.73318749],
#        [0.73497838],
#        [0.71782856],
#        [0.72259739],
#        [0.71687963],
#        [0.68868423],
#        [0.65938116],
#        [0.68092022],
#        [0.68145163]])

# %%
# Save the LSTM model
lstm_model.save("saved_discharge-model.h5")

# %%
# Visualize the predicted stock costs with actual stock costs
train_data=test_dataset.iloc[0:1500]
valid_data=test_dataset.iloc[1500:]
valid_data['Predictions']=discharge
plt.plot(train_data["Price"])
plt.plot(valid_data[['Price',"Predictions"]])
# Out:
# [<matplotlib.lines.Line2D at 0x26fd647be80>,
#  <matplotlib.lines.Line2D at 0x26fd647bf40>]

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

rms = sqrt(mean_squared_error(valid_data['Price'], valid_data['Predictions']))
rms
# Out:
# 94.91990433077653
